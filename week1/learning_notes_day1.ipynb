# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
s=50+50
print(s)
# Out:
# 100

# %%
a=5
b='ArithmeticError'

a = 5
b = "hello"

# Changing variable type
a = 5  # integer
a = "change"  # string

print(a,b)
# Out:
# change hello

# %%
# Addition, Subtraction, Multiplication, Division
print(4 + 2)      # Output: 6
print(5 - 3)      # Output: 2
print(2 * 3)      # Output: 6
print(8 / 2)      # Output: 4.0 (float result)
print(8/3)

# Exponentiation and Modulus
print(3 ** 2)     # Output: 9
print(5 % 2)      # Output: 1
# Out:
# 6
# 2
# 6
# 4.0
# 2.6666666666666665
# 9
# 1

# %%
import math
print(len("Hello"))  # Output: 5
print (math.sqrt(17))  # Output: 4.0
# Out:
# 5
# 4.123105625617661

# %%
greeting= "Hello"
name = input("what is your name ")
#int(name.character(0))
print(greeting + " " + name)
# Out:
# Hello rahul

# %%
#if -else statement
num=int(input("Enter a number: "))
if num>0:
    print("The number is positive.")
elif num<0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# The number is zero.

# %%
# loops 
mixed_list = [1, "hello", 3.14, True]
for i in mixed_list:
    print(type(i))

while mixed_list:
    print(mixed_list.pop())
while len(mixed_list)>0:
    print(mixed_list.pop())
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# True
# 3.14
# hello
# 1

# %%
#DATA STRUCTURES
# Lists
my_list = [1, 2, 3, "hello", 4.5]
print(my_list[0])  # Output: 1
#tuple
my_tuple = (1, 2, 3, "hello", 4.5 )
print(my_tuple[0])  # Output: 1
# Out:
# 1
# 1
